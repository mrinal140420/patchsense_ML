# %%
import pandas as pd
from pathlib import Path
import os

PROJECT_ROOT = Path.cwd()
while not (PROJECT_ROOT / "data").exists():
    PROJECT_ROOT = PROJECT_ROOT.parent

X = pd.read_parquet(PROJECT_ROOT / "data" / "processed" / "features.parquet")
labels = pd.read_parquet(PROJECT_ROOT / "data" / "processed" / "labels.parquet")

X.shape, labels.shape
# Out:
# ((326099, 11), (326099, 4))

# %%
labels["priority_label"] = labels["has_exploit_ref"].astype(int)

labels["priority_label"].mean()
# Out:
# np.float64(0.2465079623059255)

# %%
LABELED_FILE = PROJECT_ROOT / "data" / "processed" / "labeled.parquet"

labels[[
    "cve_id",
    "year",
    "cvss",
    "priority_label"
]].to_parquet(LABELED_FILE)

LABELED_FILE
# Out:
# WindowsPath('d:/MRINAL/CYDL/data/processed/labeled.parquet')
